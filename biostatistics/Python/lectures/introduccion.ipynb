# %% [markdown]
# # Inducción
#
# ## Software curso
# Jasp: https://jasp-stats.org/
#
# ## Datos Profesor
#  - Omar Piña Ramírez
#  - Torre de Investigación 4.6
#  - delozath@gmail.com
#  - Telegram: @delozath

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
fname = '/home/omarpr/Dropbox/Brain/data/cursos/bioestadistica/src/introduccion/db_sim_intro.csv'
#
data = pd.read_csv(fname)

# %%
data.var1.hist()
# Out:
# <Axes: >

# %%
sns.histplot(x='var1', hue='var7', bins=15, data=data)
# Out:
# <Axes: xlabel='var1', ylabel='Count'>

# %%
sns.pairplot(hue='var5', data=data)

# %%
data.head()
# Out:
#    var1      var2  var3  var4 var5  var6      var7
# 0    99 -0.023021    30     2    F     7     negro
# 1   108 -0.551201    36     4    F     9     negro
# 2   118 -0.573858    30     1    F     8  amarillo
# 3    95  0.151385    29     2    M     2     verde
# 4    95  0.655370    25     4    F     8      azul
