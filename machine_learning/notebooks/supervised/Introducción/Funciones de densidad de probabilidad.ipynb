# %%
import numpy             as np
import matplotlib.pyplot as plt

# %%
def plot_di(X,Y,L):
    plt.figure( figsize=(10,5) )
    plt.plot(X,Y,'o',markersize=20)
    plt.plot(X,L,color='orange',linewidth=3)
    
    for i,j,k in zip(X,Y,L):
        plt.arrow(i,k,0,j-k,color='black')

    plt.grid(True)

# %%
def gaussian(m,s,x):
    return ( (2*np.pi*s**2)**-.5 ) * np.exp(  -(2*s**2)**-1*(x-m)**2  )

# %% [markdown]
# ## Distribución Cauchy
# $$p(x,x_0,\lambda)=\dfrac{1}{\pi}\left(\dfrac{\lambda}{(x-x_0)^2+\lambda^2}\right)$$

# %%
#Cauchy
l  = .5
x0 = 1

y = 1/np.pi * (  l/( (x-x0)**2 + l**2 )  )

idx = np.arange(N)
np.random.shuffle(idx)

plt.plot(x,y)
plt.plot( x[idx[:k]],y[idx[:k]],'o' )

# %% [markdown]
# ## Distribución normal (Gaussiana)
#
# $$\mathcal{N}(x,\mu,\sigma)=\dfrac{1}{ (2\pi\sigma^2)^{1/2}  }exp\left\{ -\dfrac{1}{2\sigma^2} (x-\mu)^2\right\}$$
#
# $$\mathcal{N}(x,\mu,\Sigma)=\dfrac{1}{(2\pi)^{D/2}} \dfrac{1}{|\Sigma|^{1/2}} exp\left\{ \dfrac{1}{2} (x-\mu)^T\Sigma^{-1} (x-\mu) \right\}$$

# %%
N = 250
k = 50
x = np.linspace(-5,5,N)
y = gaussian( 0,2,x )

idx = np.arange(N)
np.random.shuffle(idx)

plt.plot(x,y)
plt.plot( x[idx[:k]],y[idx[:k]],'o' )

# %%
N  = 1000
pg = np.random.gamma(1,2,N)

X

plt.figure( figsize=(10,5) )
plt.plot(X,L,color='orange',linewidth=3)
# Out:
# array([0.36528748, 3.98525892, 2.58599314, 1.74290407, 0.01914731,
#        3.31893085, 0.76442593, 2.2382145 , 0.52496085, 5.56938384])
